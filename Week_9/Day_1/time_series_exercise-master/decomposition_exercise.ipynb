# %% [markdown]
# ## Decomposition Exercise

# %%
# import pandas
import pandas as pd

# import statsmodels.api as sm
import statsmodels.api as sm

# import matplotlib
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)

from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# load data
data = sm.datasets.co2.load_pandas()
co2 = data.data

# %% [markdown]
# * print the top 5 rows

# %%
co2.head()
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4

# %% [markdown]
# * Resample the time series using monthly averages and store the new time series as a Series `y`.

# %%
y = co2.resample('M').mean()

# %% [markdown]
# * print the top 5 rows of 'y'

# %%
y.head()
# Out:
#                    co2
# 1958-03-31  316.100000
# 1958-04-30  317.200000
# 1958-05-31  317.433333
# 1958-06-30         NaN
# 1958-07-31  315.625000

# %% [markdown]
# * check for missing values

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 526 entries, 1958-03-31 to 2001-12-31
# Freq: M
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   co2     521 non-null    float64
# dtypes: float64(1)
# memory usage: 8.2 KB

# %% [markdown]
# * replace missing values with last available value
#
#
#     - Example: If Feb 2010 is missing, use the value from Jan 2010.

# %%
y = y.fillna(method='bfill')

# %% [markdown]
# * plot the time series `y`

# %%
y.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# * Apply and plot the following:
#
#
#     1. additive seasonal decomposition
#     2. multiplicative seasonal decomposition

# %%
additive_decompose = seasonal_decompose(y, model='additive')
additive_decompose.plot()
plt.show()

# %%
multiplicative_decompose = seasonal_decompose(y, model='multiplicative')
multiplicative_decompose.plot()
plt.show()
