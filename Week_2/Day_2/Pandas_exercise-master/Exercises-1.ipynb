# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %% [markdown]
# ### Download the data and load it to Pandas.
#
# You can find them [here](https://drive.google.com/file/d/1NY6cmF9Shjw-dD7BD6bNmfcIVz-kQcFR/view?usp=sharing).

# %%
titles = pd.read_csv('data/titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.read_csv('data/cast.csv', sep=",")
# Out:
#                                                title  year  \
# 0                                     Closet Monster  2015
# 1                                    Suuri illusioni  1985
# 2                                Battle of the Sexes  2017
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 0                   Buffy #1  actor                                 Buffy 4
# 1                     Homo $  actor                                  Guests
# 2                    $hutter  actor                         Bobby Riggs Fan
# ...

# %%
cast.head(20)
# Out:
#                                                 title  year  \
# 0                                      Closet Monster  2015
# 1                                     Suuri illusioni  1985
# 2                                 Battle of the Sexes  2017
# 3                                Secret in Their Eyes  2015
# 4                                          Steve Jobs  2015
# 5                              Straight Outta Compton  2015
# 6                              Straight Outta Compton  2015
# 7                                      For Thy Love 2  2009
# 8   Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                        Desire (III)  2014
# 10                            When the Man Went South  2014
# 11                            Little Angel (Angelita)  2015
# 12                                         Mixing Nia  1998
# 13                                   The Replacements  2000
# 14                               All Out Dysfunktion!  2016
# ...

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
titles.count()
# Out:
# title    232330
# year     232330
# dtype: int64

# %%
len(titles)
# Out:
# 232330

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
titles.sort_values(by='year')[0:2]
# Out:
#                      title  year
# 177757          Miss Jerry  1894
# 215272  The Startled Lover  1898

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
titles[titles['title'] == 'Hamlet']
# Out:
#          title  year
# 6009    Hamlet  1948
# 45350   Hamlet  1990
# 46721   Hamlet  1910
# 92146   Hamlet  1976
# 94355   Hamlet  1987
# 94554   Hamlet  2000
# 98554   Hamlet  1921
# 102919  Hamlet  2011
# 122704  Hamlet  1969
# 128388  Hamlet  1954
# 166410  Hamlet  1913
# 168965  Hamlet  2015
# 176069  Hamlet  2009
# 182970  Hamlet  1964
# 201291  Hamlet  1996
# 209878  Hamlet  1911
# 221479  Hamlet  1973
# 223568  Hamlet  2014

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
titles[titles['title'] == 'North by Northwest'].count()
# Out:
# title    1
# year     1
# dtype: int64

# %%
titles[titles['title'] == 'North by Northwest'].count()

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
titles[titles['title'] == 'Hamlet'].sort_values(by='year')
# Out:
#          title  year
# 46721   Hamlet  1910
# 209878  Hamlet  1911
# 166410  Hamlet  1913
# 98554   Hamlet  1921
# 6009    Hamlet  1948
# 128388  Hamlet  1954
# 182970  Hamlet  1964
# 122704  Hamlet  1969
# 221479  Hamlet  1973
# 92146   Hamlet  1976
# 94355   Hamlet  1987
# 45350   Hamlet  1990
# 201291  Hamlet  1996
# 94554   Hamlet  2000
# 176069  Hamlet  2009
# 102919  Hamlet  2011
# 223568  Hamlet  2014
# 168965  Hamlet  2015

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
titles[titles['title'] == 'Treasure Island']
# Out:
#                   title  year
# 51287   Treasure Island  1920
# 89534   Treasure Island  1972
# 96934   Treasure Island  1950
# 111343  Treasure Island  1973
# 179354  Treasure Island  1999
# 191050  Treasure Island  1934
# 205397  Treasure Island  1985
# 206027  Treasure Island  1918

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
titles[titles['year'] == 1950].count()
# Out:
# title    1099
# year     1099
# dtype: int64

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
titles[titles['year'] == 1960].count()
# Out:
# title    1501
# year     1501
# dtype: int64

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
len(titles[np.isin(titles['year'],[range(1950,1960)])])
# Out:
# 12711

# %%
titles[(titles['year'] >= 1950) & (titles['year'] <= 1959) ].count()
# Out:
# title    12711
# year     12711
# dtype: int64

# %%
titles[titles["year"].between(1950,1959, "both")]
# Out:
#                                          title  year
# 40      La momia azteca contra el robot humano  1958
# 45                                 Mavi boncuk  1958
# 71                            Campo O' Donnell  1950
# 90                            Botta e risposta  1950
# 92                         Perdeu-se um Marido  1957
# ...                                        ...   ...
# 232174               Dimas: The Sainted Robber  1952
# 232196                    Tischlein, deck dich  1956
# 232231                        Some Like It Hot  1959
# 232260                             Black Widow  1951
# 232291                       Te sigo esperando  1952
#
# [12711 rows x 2 columns]

# %%
len(titles[titles['year'] //10 * 10 == 1950])
# Out:
# 12711

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
titles[titles['title'] == 'Batman']['year']
# Out:
# 56000    1989
# 74608    1943
# Name: year, dtype: int64

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
len(cast[cast['title'] == 'Inception'])
# Out:
# 77

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
len(cast[(cast['title'] == 'Inception') & np.isnan(cast['n']) ])
# Out:
# 26

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
len(cast[(cast['title'] == 'Inception') & ~np.isnan(cast['n']) ])
# Out:
# 51

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast[(cast['title'] == 'North by Northwest') & ~np.isnan(cast['n'])].sort_values(['n'])
# Out:
#                       title  year                  name     type  \
# 845516   North by Northwest  1959            Cary Grant    actor
# 3382934  North by Northwest  1959       Eva Marie Saint  actress
# 1413409  North by Northwest  1959           James Mason    actor
# 3043261  North by Northwest  1959   Jessie Royce Landis  actress
# 345822   North by Northwest  1959        Leo G. Carroll    actor
# 2941468  North by Northwest  1959  Josephine Hutchinson  actress
# 1644542  North by Northwest  1959           Philip Ober    actor
# 1236791  North by Northwest  1959         Martin Landau    actor
# 2372617  North by Northwest  1959         Adam Williams    actor
# 1757154  North by Northwest  1959          Edward Platt    actor
# 646039   North by Northwest  1959     Robert Ellenstein    actor
# 2225858  North by Northwest  1959          Les Tremayne    actor
# 450691   North by Northwest  1959       Philip Coolidge    actor
# ...

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[(cast['title'] == 'Sleuth') & (cast['year'] == 1972) & ~np.isnan(cast['n'])].sort_values(['n'])
# Out:
#           title  year                name     type  \
# 1654402  Sleuth  1972    Laurence Olivier    actor
# 316652   Sleuth  1972       Michael Caine    actor
# 362592   Sleuth  1972      Alec Cawthorne    actor
# 1421434  Sleuth  1972  John (II) Matthews    actor
# 2635708  Sleuth  1972  Eve (III) Channing  actress
# 1405219  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1654402                 Andrew Wyke  1.0
# 316652                  Milo Tindle  2.0
# 362592            Inspector Doppler  3.0
# 1421434  Detective Sergeant Tarrant  4.0
# 2635708             Marguerite Wyke  5.0
# 1405219      Police Constable Higgs  6.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
cast[(cast['title'] == 'Sleuth') & (cast['year'] == 2007) & ~np.isnan(cast['n'])].sort_values(['n'])
# Out:
#           title  year           name   type    character    n
# 316653   Sleuth  2007  Michael Caine  actor       Andrew  1.0
# 1254632  Sleuth  2007       Jude Law  actor         Milo  2.0
# 1751872  Sleuth  2007  Harold Pinter  actor  Man on T.V.  3.0

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[(cast['title'] == 'Hamlet') & (cast['year'] == 1921)]
# Out:
#           title  year                    name     type         character    n
# 7488     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 444994   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 538568   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1102007  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2119366  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2303412  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2578993  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2954242  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3229662  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast[(cast['title'] == 'Hamlet') & (cast['year'] == 1996)].count()
# Out:
# title        54
# year         54
# name         54
# type         54
# character    54
# n            46
# dtype: int64

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast[(cast['title'] == 'Hamlet')].count()
# Out:
# title        313
# year         313
# name         313
# type         313
# character    313
# n            248
# dtype: int64

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast[cast['character'] == 'Ophelia']
# Out:
#                                    title  year                  name     type  \
# 240366        The Merry Maids of Madness  2016           Amy Bourque    actor
# 397692                    Jake Gets Paid  2009        Josie Chisholm    actor
# 456673                        Inoperable  2016       Crystal Cordero    actor
# 840572   Dogg's Hamlet, Cahoot's Macbeth  2005         Lucas Grabeel    actor
# 1323306                               11  2014   Catherine (IV) Lord    actor
# ...                                  ...   ...                   ...      ...
# 3561046         Hamlet, Son of a Kingpin  2015        Ingrid Vollset  actress
# 3574490                         D.C. Cab  1983       Marsha Warfield  actress
# 3575192                         Creature  2011  Jennifer Lynn Warren  actress
# 3585205                           Hamlet  2015       Katie (II) West  actress
# 3601799                           Hamlet  1996          Kate Winslet  actress
#
#         character     n
# ...

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast['character'] == 'The Dude']
# Out:
#                                   title  year                  name   type  \
# 263434                 The Big Lebowski  1998          Jeff Bridges  actor
# 328939               Terms & Conditions  2015           Jordan Cann  actor
# 483781                         Stranger  2000         Scott Crowell  actor
# 553260           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 592594                      Sweepstakes  1931           Mike Donlin  actor
# 610856                    Self Helpless  2010        Devin The Dude  actor
# 1057654  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1105485                   Explicit Ills  2008    Christopher Kadish  actor
# 1325956                 American Idiots  2013      Jason Loughridge  actor
# 1344790             The Winds of Autumn  1976           Steve Lyons  actor
# 1467445                         The Liq  2016        Mark Alan Meek  actor
# ...

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast['character'] == 'The Stranger']
# Out:
#                             title  year                       name     type  \
# 25003                       Theeb  2014  Hassan Mutlag Al-Maraiyeh    actor
# 34533              My Time to Die  2014       Vincent H. Alexander    actor
# 65182                    Get Mean  1975               Tony Anthony    actor
# 65185    Lo straniero di silenzio  1968               Tony Anthony    actor
# 65187      Un dollaro tra i denti  1967               Tony Anthony    actor
# ...                           ...   ...                        ...      ...
# 3087925              The Stranger  1995                 Kathy Long  actress
# 3101453            Ever Since Eve  1921                Ethel Lynne  actress
# 3277027              Weitertanzen  2008             Rosa Maria Paz  actress
# 3297806               The Godsend  1980           Angela Pleasence  actress
# 3429093                Motherland  1927            Dorinea Shirley  actress
#
#             character    n
# 25003    The Stranger  3.0
# ...

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[cast['name'] == 'Sidney Poitier']
# Out:
#                                 title  year            name   type  \
# 1761853               A Patch of Blue  1965  Sidney Poitier  actor
# 1761854         A Piece of the Action  1977  Sidney Poitier  actor
# 1761855           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1761856               A Warm December  1973  Sidney Poitier  actor
# 1761857             All the Young Men  1960  Sidney Poitier  actor
# 1761858                Band of Angels  1957  Sidney Poitier  actor
# 1761859             Blackboard Jungle  1955  Sidney Poitier  actor
# 1761860                  Brother John  1971  Sidney Poitier  actor
# 1761861         Buck and the Preacher  1972  Sidney Poitier  actor
# 1761862      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1761863                Duel at Diablo  1966  Sidney Poitier  actor
# 1761864              Edge of the City  1957  Sidney Poitier  actor
# 1761865               For Love of Ivy  1968  Sidney Poitier  actor
# ...

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast['name'] == 'Judi Dench']
# Out:
#                                                title  year        name  \
# 2720471                        84 Charing Cross Road  1987  Judi Dench
# 2720472                            A Handful of Dust  1988  Judi Dench
# 2720473                    A Midsummer Night's Dream  1968  Judi Dench
# 2720474                           A Room with a View  1985  Judi Dench
# 2720475                            A Study in Terror  1965  Judi Dench
# 2720476       Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2720477                                Casino Royale  2006  Judi Dench
# 2720478                                     Chocolat  2000  Judi Dench
# 2720479                                    Dead Cert  1974  Judi Dench
# 2720480                              Die Another Day  2002  Judi Dench
# 2720481                                       Doogal  2006  Judi Dench
# 2720482                          Four in the Morning  1965  Judi Dench
# ...

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
cast[(cast['name'] == 'Cary Grant') & (cast['n'] == 2) & np.isin(cast['year'],[range(1940,1950)])]
# Out:
#                    title  year        name   type    character    n
# 845513  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 845523    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
cast[(cast['name'] == 'Cary Grant') & (cast['n'] == 1) & np.isin(cast['year'],[range(1940,1950)])].sort_values(['year'])
# Out:
#                                        title  year        name   type  \
# 845539               The Howards of Virginia  1940  Cary Grant  actor
# 845495                       His Girl Friday  1940  Cary Grant  actor
# 845541                The Philadelphia Story  1940  Cary Grant  actor
# 845528                             Suspicion  1941  Cary Grant  actor
# 845543                  The Talk of the Town  1942  Cary Grant  actor
# 845519                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 845486                     Destination Tokyo  1943  Cary Grant  actor
# 845511                             Mr. Lucky  1943  Cary Grant  actor
# 845512                             Mr. Lucky  1943  Cary Grant  actor
# 845520                      Once Upon a Time  1944  Cary Grant  actor
# 845478                  Arsenic and Old Lace  1944  Cary Grant  actor
# 845515             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %%
[range(1950,1960)]
# Out:
# [range(1950, 1960)]

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[(cast['type'] == 'actor') & cast['year'].isin(list(range(1950,1960))) ]
# Out:
#                            title  year                  name   type  \
# 68               Fire Down Below  1957  'Stretch' Cox Troupe  actor
# 70            Dorp aan de rivier  1958         Frans 't Hoen  actor
# 115         Ci sposeremo a Capri  1956         Quartetto 2+2  actor
# 122               Die Todesarena  1953      Die 3 Motorellos  actor
# 270             Palletoori Pilla  1950        Subba Rao A.V.  actor
# ...                          ...   ...                   ...    ...
# 2455117         Salve sauegjeter  1958           ?yvind ?yen  actor
# 2455125          La noche avanza  1952       Francisco ?beda  actor
# 2455188                Yaban kiz  1954             Memduh ?n  actor
# 2455297  Barbaros Hayrettin Pasa  1951          Ali ?st?ntas  actor
# 2455298                 Kara Efe  1952          Ali ?st?ntas  actor
#
#                    character     n
# 68            Limbo Dance by  20.0
# 70                  Dirk Jan  15.0
# 115               Themselves  19.0
# ...

# %% [markdown]
# ### How many roles were avilable for actresses in the 1950s?

# %%
cast[(cast['type'] == 'actress') & cast['year'].isin(list(range(1950,1960))) ]
# Out:
#                           title  year               name     type  \
# 2455338  A Woman of Distinction  1950  Lucienne & Ashour  actress
# 2455340         Chain Lightning  1950  Lucienne & Ashour  actress
# 2455346    De moedige bruidegom  1952     Hilda 't Seyen  actress
# 2455376       Cuban Rebel Girls  1959    Beverly Aadland  actress
# 2455377     Death of a Salesman  1951    Beverly Aadland  actress
# ...                         ...   ...                ...      ...
# 3634357        Styrmand Karlsen  1958         Clara ?st?  actress
# 3634358        Styrmand Karlsen  1958         Clara ?st?  actress
# 3634360   Tre piger fra Jylland  1957         Clara ?st?  actress
# 3634374                    Toya  1956         Aslaug ?ye  actress
# 3634392      Akdeniz korsanlari  1950    Muazzez ?lkerer  actress
#
#                      character     n
# 2455338         Apache Dancers   NaN
# 2455340         Apache Dancers   NaN
# 2455346  De moeder van Tinneke   NaN
# ...

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast[(cast['n'] == 1) & (cast['year'] <= 1980) ]
# Out:
#                                      title  year               name     type  \
# 281                           En glad gutt  1932         Hauk Aabel    actor
# 286                      En herre med bart  1942          Per Aabel    actor
# 1030                 Batman Fights Dracula  1967        Jing Abalos    actor
# 1031                 Batman Fights Dracula  1967        Jing Abalos    actor
# 1035                           Mighty Rock  1969        Jing Abalos    actor
# ...                                    ...   ...                ...      ...
# 3633836    Jokosei: natsu hiraku kuchiburu  1980          Ayako ?ta  actress
# 3633838  Kairaku gakuen: kinjirareta asobi  1980          Ayako ?ta  actress
# 3633855                    Ah! Nomugi toge  1979      Shinobu ?take  actress
# 3634001                          Kvinnolek  1968  Gunbritt ?hrstr?m  actress
# 3634046                 Tamam mi devam mi?  1975         F?sun ?nal  actress
#
# ...

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
cast[(cast['n'] != 1) & (cast['year'] <= 1980) ]
# Out:
#                                             title  year  \
# 20                                 Natas es Satan  1977
# 32                                   Los tarantos  1963
# 34                                   Los tarantos  1963
# 41       Been Down So Long It Looks Like Up to Me  1971
# 42                         I Wanna Hold Your Hand  1978
# ...                                           ...   ...
# 3634382                                    Venner  1960
# 3634386                                     Bang!  1977
# 3634387                               Alin yazisi  1972
# 3634390                               Tokmak Nuri  1975
# 3634392                        Akdeniz korsanlari  1950
#
#                           name     type         character     n
# 20       Ramon 'Cartucho' Pena    actor  Nigth Club Owner   NaN
# 32                  'El Guisa'    actor           Bailaor  25.0
# 34                   'El Viti'    actor           Cantaor  20.0
# ...

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
cast[(cast['n'].isnull()) & (cast['year'] <= 1980) ]
# Out:
#                                             title  year  \
# 20                                 Natas es Satan  1977
# 41       Been Down So Long It Looks Like Up to Me  1971
# 117                             Atemlos vor Liebe  1970
# 119                           Thunder in Carolina  1960
# 122                                Die Todesarena  1953
# ...                                           ...   ...
# 3634272                                     Hanci  1969
# 3634298                                     4 x 4  1965
# 3634382                                    Venner  1960
# 3634386                                     Bang!  1977
# 3634390                               Tokmak Nuri  1975
#
#                              name     type                    character   n
# 20          Ramon 'Cartucho' Pena    actor             Nigth Club Owner NaN
# 41                 Murray the 'K'    actor                      Himself NaN
# ...
